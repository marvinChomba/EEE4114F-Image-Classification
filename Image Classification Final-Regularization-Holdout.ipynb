# %%
import tensorflow as tf
import os

# %%
# import cv2
# import imghdr

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data3')
# Out:
# Found 3000 files belonging to 6 classes.

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
scaled_iterator = data.as_numpy_iterator() 


batch = scaled_iterator.next() #images represented as numpy arrays

# print(batch[0].shape)

fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %%
len(data)*0.7 #batches

# %%
train_size = int(len(data)*.3) #to train
val_size = int(len(data)*.6) #to evaluate while training
test_size = int(len(data)*.1) #to test

# %%
val_size

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
len(test)
# Out:
# 9

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(256,256,3), kernel_regularizer=tf.keras.regularizers.L2(l=0.01)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(32, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l=0.01)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(16, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l=0.01)))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(6, activation='softmax'))

# %%
model.compile('adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 128)               1843328
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 1,858,870
# Trainable params: 1,858,870
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='logs' #

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir) #to save model

# %%
train[1]

# %%
# hist = model.fit(train, epochs=3, validation_data=val,callbacks=[tensorboard_callback])
hist = model.fit(train, epochs=10, validation_data=val)
# Out:
# Epoch 1/10
# 28/28 [==============================] - 49s 2s/step - loss: 2.2641 - accuracy: 0.3114 - val_loss: 1.9677 - val_accuracy: 0.3532
# Epoch 2/10
# 28/28 [==============================] - 38s 1s/step - loss: 1.6576 - accuracy: 0.5223 - val_loss: 1.5577 - val_accuracy: 0.5458
# Epoch 3/10
# 28/28 [==============================] - 36s 1s/step - loss: 1.4027 - accuracy: 0.5748 - val_loss: 1.4192 - val_accuracy: 0.5815
# Epoch 4/10
# 28/28 [==============================] - 35s 1s/step - loss: 1.2821 - accuracy: 0.6161 - val_loss: 1.5511 - val_accuracy: 0.5530
# Epoch 5/10
# 28/28 [==============================] - 38s 1s/step - loss: 1.2311 - accuracy: 0.6373 - val_loss: 1.3136 - val_accuracy: 0.6049
# Epoch 6/10
# 28/28 [==============================] - 38s 1s/step - loss: 1.0826 - accuracy: 0.6987 - val_loss: 1.3318 - val_accuracy: 0.6150
# Epoch 7/10
# 28/28 [==============================] - 39s 1s/step - loss: 0.9755 - accuracy: 0.7422 - val_loss: 1.3791 - val_accuracy: 0.5949
# Epoch 8/10
# 28/28 [==============================] - 39s 1s/step - loss: 0.8544 - accuracy: 0.7879 - val_loss: 1.4090 - val_accuracy: 0.6010
# Epoch 9/10
# 28/28 [==============================] - 39s 1s/step - loss: 0.7336 - accuracy: 0.8359 - val_loss: 1.3657 - val_accuracy: 0.6105
# Epoch 10/10
# 28/28 [==============================] - 40s 1s/step - loss: 0.6076 - accuracy: 0.8795 - val_loss: 1.4408 - val_accuracy: 0.6367

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(f'Precision:{pre.result().numpy()}, Recall: {re.result().numpy()},Accuracy: {acc.result().numpy()}')

# %%
import cv2
img = cv2.imread('265.png')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))

# %%
yhat

# %%
if yhat < 0.5: 
    print(f'Predicted class is Circle')
else:
    print(f'Predicted class is Square')
